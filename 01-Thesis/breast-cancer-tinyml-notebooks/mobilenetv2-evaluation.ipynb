# %%
# Import Dependencies

import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix, precision_recall_fscore_support
# Out:
# 2025-11-12 17:52:14.893961: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762969934.916851     392 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762969934.923647     392 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'

# %%
# Paths

root = "/kaggle/input/breast-cancer-detection-mri/Breast_Cancer_MRI_Dataset"
IMG_SIZE = (512, 512)
BATCH = 16
SEED = 42
AUTOTUNE = tf.data.AUTOTUNE

# %%
# Load dataset

preprocess_fn = tf.keras.applications.mobilenet_v2.preprocess_input

def build_ds(subdir, augment=False, shuffle=False):
    ds = tf.keras.utils.image_dataset_from_directory(
        os.path.join(root, subdir),
        labels="inferred",
        label_mode="int",
        color_mode="rgb",
        batch_size=BATCH,
        image_size=IMG_SIZE,
        shuffle=shuffle,
        seed=SEED
    )

    aug = keras.Sequential([
        layers.RandomFlip("horizontal_and_vertical"),
        layers.RandomRotation(0.05),
        layers.RandomContrast(0.1),
        layers.RandomZoom(0.1)
    ]) if augment else None

    def _map(x, y):
        x = tf.cast(x, tf.float32)
        if aug is not None:
            x = aug(x, training=True)
        x = preprocess_fn(x)
        return x, y

    return (ds.map(_map, num_parallel_calls=AUTOTUNE)
              .cache()
              .prefetch(AUTOTUNE))

train_ds = build_ds("train", augment=True, shuffle=True)
val_ds   = build_ds("validation", augment=False, shuffle=False)
test_ds  = build_ds("test", augment=False, shuffle=False)
# Out:
# Found 4000 files belonging to 2 classes.
# I0000 00:00:1762969943.142208     392 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1762969943.142870     392 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Found 400 files belonging to 2 classes.
# Found 400 files belonging to 2 classes.

# %%
# Evaluate with best threshold

# Load the model
from tensorflow.keras.models import load_model
model_mobilenetv2 = load_model("/kaggle/input/mobilenetv2/tensorflow2/default/1/MOBILENETV2.keras")

def best_threshold(ds):
    y_true = np.concatenate([y for _, y in ds], axis=0)
    y_prob = model_mobilenetv2small.predict(ds, verbose=0).ravel()
    fpr, tpr, thr = roc_curve(y_true, y_prob)
    youden = tpr - fpr
    return thr[np.argmax(youden)]

thr = best_threshold(val_ds)
print("Best threshold:", thr)

def metrics_at_threshold(ds, thr):
    y_true = np.concatenate([y for _, y in ds], axis=0)
    y_prob = model_mobilenetv2small.predict(ds, verbose=0).ravel()
    y_pred = (y_prob >= thr).astype(int)
    auc = roc_auc_score(y_true, y_prob)
    cm = confusion_matrix(y_true, y_pred)
    prec, rec, f1, _ = precision_recall_fscore_support(y_true, y_pred, average="binary")
    tn, fp, fn, tp = cm.ravel()
    spec = tn / (tn + fp)
    return dict(auc=auc, precision=prec, recall=rec, f1=f1, specificity=spec, cm=cm)

print("Validation metrics:", metrics_at_threshold(val_ds, thr))
print("Test metrics:", metrics_at_threshold(test_ds, thr))
# Out:
# Best threshold: 0.16740167
# Validation metrics: {'auc': 0.9914749999999999, 'precision': 0.9747474747474747, 'recall': 0.965, 'f1': 0.9698492462311558, 'specificity': 0.975, 'cm': array([[195,   5],
#        [  7, 193]])}
# Test metrics: {'auc': 0.977175, 'precision': 0.9261083743842364, 'recall': 0.94, 'f1': 0.9330024813895781, 'specificity': 0.925, 'cm': array([[185,  15],
#        [ 12, 188]])}

# %%
# !pip install tensorflow_model_optimization
import tensorflow_model_optimization as tfmot
# Out:
# Collecting tensorflow_model_optimization
#   Downloading tensorflow_model_optimization-0.8.0-py2.py3-none-any.whl.metadata (904 bytes)
# Requirement already satisfied: absl-py~=1.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow_model_optimization) (1.4.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow_model_optimization) (0.1.9)
# Requirement already satisfied: numpy~=1.23 in /usr/local/lib/python3.11/dist-packages (from tensorflow_model_optimization) (1.26.4)
# Requirement already satisfied: six~=1.14 in /usr/local/lib/python3.11/dist-packages (from tensorflow_model_optimization) (1.17.0)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.11/dist-packages (from dm-tree~=0.1.1->tensorflow_model_optimization) (25.4.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.11/dist-packages (from dm-tree~=0.1.1->tensorflow_model_optimization) (1.17.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy~=1.23->tensorflow_model_optimization) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy~=1.23->tensorflow_model_optimization) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy~=1.23->tensorflow_model_optimization) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy~=1.23->tensorflow_model_optimization) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy~=1.23->tensorflow_model_optimization) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy~=1.23->tensorflow_model_optimization) (2.4.1)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy~=1.23->tensorflow_model_optimization) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy~=1.23->tensorflow_model_optimization) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy~=1.23->tensorflow_model_optimization) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy~=1.23->tensorflow_model_optimization) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy~=1.23->tensorflow_model_optimization) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy~=1.23->tensorflow_model_optimization) (2024.2.0)
# Downloading tensorflow_model_optimization-0.8.0-py2.py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 5.4 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: tensorflow_model_optimization
# Successfully installed tensorflow_model_optimization-0.8.0

# %%
# Create the TFLite converter
converter = tf.lite.TFLiteConverter.from_keras_model(model_mobilenetv2)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_types = [tf.float16]

# Convert the model
tflite_quant_model = converter.convert()
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpmn7i4j67/assets
# INFO:tensorflow:Assets written to: /tmp/tmpmn7i4j67/assets
# Saved artifact at '/tmp/tmpmn7i4j67'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 512, 512, 3), dtype=tf.float32, name='input_layer_2')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   140412418967504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418969232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418969616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418969424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418968080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418968656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418971344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418971728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418971536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418967120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418972880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418973264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418973648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418973456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418970384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418974800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418975184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418975568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418975376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418970960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418976720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418977104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418977488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418977296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418972496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418978640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418979024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418979408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418979216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418974416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418980560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418980944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418981712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418981136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418976336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418968848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360360976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360360016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418978256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360361360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360362512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360362896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360363280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360363088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360360400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360364432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360364816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360365200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360365008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360360592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360366352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360366736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360367120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360366928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360362128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360368272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360368656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360369040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360368848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360364048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360370192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360370576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360370960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360370768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360365968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360372112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360372496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360372880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360372688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360367888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360374032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360374416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360374800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360374608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360369808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360375952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360361168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017639696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360375568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360373648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017641040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017641424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017641808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017641616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017639888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017642960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017643344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017643728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017643536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017640464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017644880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017645264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017645648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017645456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017640272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017646800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017647184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017647568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017647376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017642576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017648720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017649104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017649488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017649296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017644496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017650640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017651024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017651408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017651216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017646416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017652560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017652944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017653328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017653136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017648336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017654480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017654864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017655632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017655056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017650256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017640656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017968144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017967184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017652176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017967376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017969680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017970064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017970448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017970256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017967568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017971600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017971984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017972368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017972176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017968528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017973520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017973904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017974288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017974096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017969296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017975440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017975824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017976208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017976016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017971216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017977360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017977744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017978128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017977936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017973136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017979280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017979664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017980048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017979856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017975056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017981200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017981584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017981968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017981776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017976976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017983120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017967952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018360784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017982736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017980816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018361936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018362320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018362704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018362512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018361168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018363856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018364240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018364624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018364432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018361360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018365776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018366160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018366544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018366352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018360592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018367696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018368080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018368464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018368272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018363472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018369616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018370000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018370384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018370192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018365392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018371536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018371920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018372304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018372112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018367312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018373456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018373840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018374224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018374032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018369232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018375376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018375760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018376528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018375952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018371152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018361552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016690192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016689232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018373072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016689424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016691728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016692112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016692496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016692304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016689616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016693648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016694032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016694416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016694224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016690576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016695568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016695952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016696336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016696144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016691344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016697488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016697872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016698256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016698064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016693264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016699408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016699792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016700176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016699984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016695184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016701328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016701712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016702096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016701904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016697104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016703248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016703632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016704016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016703824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016699024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016705168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016690000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017017296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016704784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016702864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017018448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017018832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017019216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017019024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017017680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017020368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017020752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017021136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017020944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017017872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017018064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017023440: TensorSpec(shape=(), dtype=tf.resource, name=None)
# W0000 00:00:1762970023.707325     392 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1762970023.707354     392 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1762970023.856849     392 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled

# %%
# Save the quantized model

with open("/kaggle/working/MobileNetV2F16Quantized.tflite", "wb") as f:
    f.write(tflite_quant_model)

# %%
# Create the TFLite converter
converter = tf.lite.TFLiteConverter.from_keras_model(model_mobilenetv2)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# Convert the model
tflite_quant_model = converter.convert()
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpsatikxlj/assets
# INFO:tensorflow:Assets written to: /tmp/tmpsatikxlj/assets
# Saved artifact at '/tmp/tmpsatikxlj'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 512, 512, 3), dtype=tf.float32, name='input_layer_2')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   140412418967504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418969232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418969616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418969424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418968080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418968656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418971344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418971728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418971536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418967120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418972880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418973264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418973648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418973456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418970384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418974800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418975184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418975568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418975376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418970960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418976720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418977104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418977488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418977296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418972496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418978640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418979024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418979408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418979216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418974416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418980560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418980944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418981712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418981136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418976336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418968848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360360976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360360016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412418978256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360361360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360362512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360362896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360363280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360363088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360360400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360364432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360364816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360365200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360365008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360360592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360366352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360366736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360367120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360366928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360362128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360368272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360368656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360369040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360368848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360364048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360370192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360370576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360370960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360370768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360365968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360372112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360372496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360372880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360372688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360367888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360374032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360374416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360374800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360374608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360369808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360375952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360361168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017639696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360375568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412360373648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017641040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017641424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017641808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017641616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017639888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017642960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017643344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017643728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017643536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017640464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017644880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017645264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017645648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017645456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017640272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017646800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017647184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017647568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017647376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017642576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017648720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017649104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017649488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017649296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017644496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017650640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017651024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017651408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017651216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017646416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017652560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017652944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017653328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017653136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017648336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017654480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017654864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017655632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017655056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017650256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017640656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017968144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017967184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017652176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017967376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017969680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017970064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017970448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017970256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017967568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017971600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017971984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017972368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017972176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017968528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017973520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017973904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017974288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017974096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017969296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017975440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017975824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017976208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017976016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017971216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017977360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017977744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017978128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017977936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017973136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017979280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017979664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017980048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017979856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017975056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017981200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017981584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017981968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017981776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017976976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017983120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017967952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018360784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017982736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017980816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018361936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018362320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018362704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018362512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018361168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018363856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018364240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018364624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018364432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018361360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018365776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018366160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018366544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018366352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018360592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018367696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018368080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018368464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018368272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018363472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018369616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018370000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018370384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018370192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018365392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018371536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018371920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018372304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018372112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018367312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018373456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018373840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018374224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018374032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018369232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018375376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018375760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018376528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018375952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018371152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018361552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016690192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016689232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412018373072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016689424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016691728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016692112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016692496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016692304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016689616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016693648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016694032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016694416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016694224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016690576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016695568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016695952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016696336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016696144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016691344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016697488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016697872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016698256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016698064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016693264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016699408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016699792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016700176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016699984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016695184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016701328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016701712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016702096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016701904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016697104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016703248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016703632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016704016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016703824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016699024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016705168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016690000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017017296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016704784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412016702864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017018448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017018832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017019216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017019024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017017680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017020368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017020752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017021136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017020944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017017872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017018064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140412017023440: TensorSpec(shape=(), dtype=tf.resource, name=None)
# W0000 00:00:1762970065.025061     392 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1762970065.025095     392 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.

# %%
# Save the quantized model

with open("/kaggle/working/MobileNetV2_Dynamic_Range_PTQ.tflite", "wb") as f:
    f.write(tflite_quant_model)

# %%
files = [
    "/kaggle/input/mobilenetv2/tensorflow2/default/1/MOBILENETV2.keras",
    "/kaggle/working/MobileNetV2_Dynamic_Range_PTQ.tflite",
    "/kaggle/working/MobileNetV2F16Quantized.tflite"
]

for f in files:
    size_mb = os.path.getsize(f) / (1024 * 1024)
    print(f"{f}: {size_mb:.2f} MB")
# Out:
# /kaggle/input/mobilenetv2/tensorflow2/default/1/MOBILENETV2.keras: 26.27 MB
# /kaggle/working/MobileNetV2_Dynamic_Range_PTQ.tflite: 2.39 MB
# /kaggle/working/MobileNetV2F16Quantized.tflite: 4.26 MB

# %% [markdown]
# ### Dynamic Range Quantized Model

# %%
# Function to get probabilities from TFLite model
def tflite_predict(interpreter, dataset):
    input_index = interpreter.get_input_details()[0]["index"]
    output_index = interpreter.get_output_details()[0]["index"]
    y_true, y_prob = [], []

    for x_batch, y_batch in dataset:
        for img, label in zip(x_batch, y_batch):
            img = np.expand_dims(img, axis=0).astype(np.float32)
            interpreter.set_tensor(input_index, img)
            interpreter.invoke()
            output = interpreter.get_tensor(output_index)[0]

            # Handle 2-class vs 1-class output
            if output.shape[0] == 2:
                prob = tf.nn.softmax(output).numpy()[1]
            else:
                prob = output[0]

            y_true.append(label)
            y_prob.append(prob)

    return np.array(y_true), np.array(y_prob)


# Load TFLite model
interpreter = tf.lite.Interpreter(model_path="/kaggle/working/MobileNetV2_Dynamic_Range_PTQ.tflite")
interpreter.allocate_tensors()


# Find best threshold (Youden’s J statistic) 
def best_threshold_tflite(interpreter, val_ds):
    y_true, y_prob = tflite_predict(interpreter, val_ds)
    fpr, tpr, thr = roc_curve(y_true, y_prob)
    youden = tpr - fpr
    return thr[np.argmax(youden)], y_true, y_prob


thr, y_true_val, y_prob_val = best_threshold_tflite(interpreter, val_ds)
print("Best threshold:", thr)


# Compute metrics at threshold 
def metrics_at_threshold_tflite(interpreter, ds, thr):
    y_true, y_prob = tflite_predict(interpreter, ds)
    y_pred = (y_prob >= thr).astype(int)

    auc = roc_auc_score(y_true, y_prob)
    cm = confusion_matrix(y_true, y_pred)
    prec, rec, f1, _ = precision_recall_fscore_support(y_true, y_pred, average="binary", zero_division=0)
    tn, fp, fn, tp = cm.ravel()
    spec = tn / (tn + fp)

    return dict(auc=auc, precision=prec, recall=rec, f1=f1, specificity=spec, cm=cm)


print("Validation metrics:", metrics_at_threshold_tflite(interpreter, val_ds, thr))
print("Test metrics:", metrics_at_threshold_tflite(interpreter, test_ds, thr))
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Best threshold: 0.101320535
# Validation metrics: {'auc': 0.9904999999999999, 'precision': 0.9698492462311558, 'recall': 0.965, 'f1': 0.9674185463659147, 'specificity': 0.97, 'cm': array([[194,   6],
#        [  7, 193]])}
# Test metrics: {'auc': 0.98075, 'precision': 0.9121951219512195, 'recall': 0.935, 'f1': 0.9234567901234569, 'specificity': 0.91, 'cm': array([[182,  18],
#        [ 13, 187]])}

# %%
from sklearn.metrics import (
    roc_curve, roc_auc_score, precision_recall_curve,
    average_precision_score, f1_score, confusion_matrix,
    precision_recall_fscore_support
)
import matplotlib.pyplot as plt
import seaborn as sns


# Get predictions from TFLite model
def tflite_predict(interpreter, dataset):
    input_index = interpreter.get_input_details()[0]["index"]
    output_index = interpreter.get_output_details()[0]["index"]
    y_true, y_prob = [], []

    for x_batch, y_batch in dataset:
        for img, label in zip(x_batch, y_batch):
            img = np.expand_dims(img, axis=0).astype(np.float32)
            interpreter.set_tensor(input_index, img)
            interpreter.invoke()
            output = interpreter.get_tensor(output_index)[0]

            # Handle 2-class vs 1-class model outputs
            if output.shape[0] == 2:
                prob = tf.nn.softmax(output).numpy()[1]
            else:
                prob = output[0]

            y_true.append(label)
            y_prob.append(prob)

    return np.array(y_true), np.array(y_prob)


# Find best threshold using Youden’s J statistic
def best_threshold_tflite(interpreter, val_ds):
    y_true, y_prob = tflite_predict(interpreter, val_ds)
    fpr, tpr, thr = roc_curve(y_true, y_prob)
    youden = tpr - fpr
    best_thr = thr[np.argmax(youden)]
    return best_thr, y_true, y_prob


# Compute metrics at threshold 
def metrics_at_threshold_tflite(interpreter, ds, thr):
    y_true, y_prob = tflite_predict(interpreter, ds)
    y_pred = (y_prob >= thr).astype(int)

    auc = roc_auc_score(y_true, y_prob)
    cm = confusion_matrix(y_true, y_pred)
    prec, rec, f1, _ = precision_recall_fscore_support(y_true, y_pred, average="binary", zero_division=0)
    tn, fp, fn, tp = cm.ravel()
    spec = tn / (tn + fp)

    return dict(auc=auc, precision=prec, recall=rec, f1=f1, specificity=spec, cm=cm, 
                y_true=y_true, y_prob=y_prob)


# Plot all diagnostic curves
def plot_medical_curves(y_true, y_prob, threshold=0.5):
    # ROC Curve
    fpr, tpr, _ = roc_curve(y_true, y_prob)
    roc_auc = roc_auc_score(y_true, y_prob)
    plt.figure(figsize=(6,5))
    plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")
    plt.plot([0,1],[0,1],'--',color='gray')
    plt.title("ROC Curve")
    plt.xlabel("False Positive Rate (1 - Specificity)")
    plt.ylabel("True Positive Rate (Sensitivity)")
    plt.legend()
    plt.show()

    # Precision–Recall Curve
    precisions, recalls, _ = precision_recall_curve(y_true, y_prob)
    pr_auc = average_precision_score(y_true, y_prob)
    plt.figure(figsize=(6,5))
    plt.plot(recalls, precisions, label=f"PR-AUC = {pr_auc:.4f}")
    plt.xlabel("Recall (Sensitivity)")
    plt.ylabel("Precision (PPV)")
    plt.title("Precision–Recall Curve")
    plt.legend()
    plt.show()

    # F1 vs Threshold Curve
    thresholds = np.linspace(0, 1, 100)
    f1s = [f1_score(y_true, (y_prob >= t).astype(int)) for t in thresholds]
    plt.figure(figsize=(6,5))
    plt.plot(thresholds, f1s)
    plt.xlabel("Threshold")
    plt.ylabel("F1 Score")
    plt.title("F1 vs Threshold Curve")
    plt.show()

    # Confusion Matrix
    y_pred = (y_prob >= threshold).astype(int)
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title(f"Confusion Matrix (Threshold = {threshold:.2f})")
    plt.show()

    print(f"ROC-AUC: {roc_auc:.4f}")
    print(f"PR-AUC: {pr_auc:.4f}")


# Load TFLite model
interpreter = tf.lite.Interpreter(model_path="/kaggle/working/MobileNetV2_Dynamic_Range_PTQ.tflite")
interpreter.allocate_tensors()


# Find best threshold using validation set
thr, y_true_val, y_prob_val = best_threshold_tflite(interpreter, val_ds)
print("Best threshold:", thr)

# Compute metrics for test set
test_metrics = metrics_at_threshold_tflite(interpreter, test_ds, thr)
print("\nTest metrics:")
for k, v in test_metrics.items():
    if k not in ["y_true", "y_prob", "cm"]:
        print(f"{k}: {v:.4f}")

# Plot all diagnostic curves for test set
plot_medical_curves(test_metrics["y_true"], test_metrics["y_prob"], threshold=thr)
# Out:
# Best threshold: 0.101320535
#
# Test metrics:
# auc: 0.9808
# precision: 0.9122
# recall: 0.9350
# f1: 0.9235
# specificity: 0.9100
# ROC-AUC: 0.9808
# PR-AUC: 0.9826

# %% [markdown]
# ### 16 bit quantized model

# %%
# Function to get probabilities from TFLite model
def tflite_predict(interpreter, dataset):
    input_index = interpreter.get_input_details()[0]["index"]
    output_index = interpreter.get_output_details()[0]["index"]
    y_true, y_prob = [], []

    for x_batch, y_batch in dataset:
        for img, label in zip(x_batch, y_batch):
            img = np.expand_dims(img, axis=0).astype(np.float32)
            interpreter.set_tensor(input_index, img)
            interpreter.invoke()
            output = interpreter.get_tensor(output_index)[0]

            # Handle 2-class vs 1-class output
            if output.shape[0] == 2:
                prob = tf.nn.softmax(output).numpy()[1]
            else:
                prob = output[0]

            y_true.append(label)
            y_prob.append(prob)

    return np.array(y_true), np.array(y_prob)


# Load TFLite model
interpreter = tf.lite.Interpreter(model_path="/kaggle/working/MobileNetV2F16Quantized.tflite")
interpreter.allocate_tensors()


# Find best threshold (Youden’s J statistic) 
def best_threshold_tflite(interpreter, val_ds):
    y_true, y_prob = tflite_predict(interpreter, val_ds)
    fpr, tpr, thr = roc_curve(y_true, y_prob)
    youden = tpr - fpr
    return thr[np.argmax(youden)], y_true, y_prob


thr, y_true_val, y_prob_val = best_threshold_tflite(interpreter, val_ds)
print("Best threshold:", thr)


# Compute metrics at threshold 
def metrics_at_threshold_tflite(interpreter, ds, thr):
    y_true, y_prob = tflite_predict(interpreter, ds)
    y_pred = (y_prob >= thr).astype(int)

    auc = roc_auc_score(y_true, y_prob)
    cm = confusion_matrix(y_true, y_pred)
    prec, rec, f1, _ = precision_recall_fscore_support(y_true, y_pred, average="binary", zero_division=0)
    tn, fp, fn, tp = cm.ravel()
    spec = tn / (tn + fp)

    return dict(auc=auc, precision=prec, recall=rec, f1=f1, specificity=spec, cm=cm)


print("Validation metrics:", metrics_at_threshold_tflite(interpreter, val_ds, thr))
print("Test metrics:", metrics_at_threshold_tflite(interpreter, test_ds, thr))
# Out:
# Best threshold: 0.16904482
# Validation metrics: {'auc': 0.991475, 'precision': 0.9651741293532339, 'recall': 0.97, 'f1': 0.9675810473815462, 'specificity': 0.965, 'cm': array([[193,   7],
#        [  6, 194]])}
# Test metrics: {'auc': 0.9765999999999999, 'precision': 0.9215686274509803, 'recall': 0.94, 'f1': 0.9306930693069307, 'specificity': 0.92, 'cm': array([[184,  16],
#        [ 12, 188]])}

# %%
from sklearn.metrics import (
    roc_curve, roc_auc_score, precision_recall_curve,
    average_precision_score, f1_score, confusion_matrix,
    precision_recall_fscore_support
)
import matplotlib.pyplot as plt
import seaborn as sns


# Get predictions from TFLite model
def tflite_predict(interpreter, dataset):
    input_index = interpreter.get_input_details()[0]["index"]
    output_index = interpreter.get_output_details()[0]["index"]
    y_true, y_prob = [], []

    for x_batch, y_batch in dataset:
        for img, label in zip(x_batch, y_batch):
            img = np.expand_dims(img, axis=0).astype(np.float32)
            interpreter.set_tensor(input_index, img)
            interpreter.invoke()
            output = interpreter.get_tensor(output_index)[0]

            # Handle 2-class vs 1-class model outputs
            if output.shape[0] == 2:
                prob = tf.nn.softmax(output).numpy()[1]
            else:
                prob = output[0]

            y_true.append(label)
            y_prob.append(prob)

    return np.array(y_true), np.array(y_prob)


# Find best threshold using Youden’s J statistic
def best_threshold_tflite(interpreter, val_ds):
    y_true, y_prob = tflite_predict(interpreter, val_ds)
    fpr, tpr, thr = roc_curve(y_true, y_prob)
    youden = tpr - fpr
    best_thr = thr[np.argmax(youden)]
    return best_thr, y_true, y_prob


# Compute metrics at threshold 
def metrics_at_threshold_tflite(interpreter, ds, thr):
    y_true, y_prob = tflite_predict(interpreter, ds)
    y_pred = (y_prob >= thr).astype(int)

    auc = roc_auc_score(y_true, y_prob)
    cm = confusion_matrix(y_true, y_pred)
    prec, rec, f1, _ = precision_recall_fscore_support(y_true, y_pred, average="binary", zero_division=0)
    tn, fp, fn, tp = cm.ravel()
    spec = tn / (tn + fp)

    return dict(auc=auc, precision=prec, recall=rec, f1=f1, specificity=spec, cm=cm, 
                y_true=y_true, y_prob=y_prob)


# Plot all diagnostic curves
def plot_medical_curves(y_true, y_prob, threshold=0.5):
    # ROC Curve
    fpr, tpr, _ = roc_curve(y_true, y_prob)
    roc_auc = roc_auc_score(y_true, y_prob)
    plt.figure(figsize=(6,5))
    plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")
    plt.plot([0,1],[0,1],'--',color='gray')
    plt.title("ROC Curve")
    plt.xlabel("False Positive Rate (1 - Specificity)")
    plt.ylabel("True Positive Rate (Sensitivity)")
    plt.legend()
    plt.show()

    # Precision–Recall Curve
    precisions, recalls, _ = precision_recall_curve(y_true, y_prob)
    pr_auc = average_precision_score(y_true, y_prob)
    plt.figure(figsize=(6,5))
    plt.plot(recalls, precisions, label=f"PR-AUC = {pr_auc:.4f}")
    plt.xlabel("Recall (Sensitivity)")
    plt.ylabel("Precision (PPV)")
    plt.title("Precision–Recall Curve")
    plt.legend()
    plt.show()

    # F1 vs Threshold Curve
    thresholds = np.linspace(0, 1, 100)
    f1s = [f1_score(y_true, (y_prob >= t).astype(int)) for t in thresholds]
    plt.figure(figsize=(6,5))
    plt.plot(thresholds, f1s)
    plt.xlabel("Threshold")
    plt.ylabel("F1 Score")
    plt.title("F1 vs Threshold Curve")
    plt.show()

    # Confusion Matrix
    y_pred = (y_prob >= threshold).astype(int)
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title(f"Confusion Matrix (Threshold = {threshold:.2f})")
    plt.show()

    print(f"ROC-AUC: {roc_auc:.4f}")
    print(f"PR-AUC: {pr_auc:.4f}")


# Load TFLite model
interpreter = tf.lite.Interpreter(model_path="/kaggle/working/MobileNetV2F16Quantized.tflite")
interpreter.allocate_tensors()


# Find best threshold using validation set
thr, y_true_val, y_prob_val = best_threshold_tflite(interpreter, val_ds)
print("Best threshold:", thr)

# Compute metrics for test set
test_metrics = metrics_at_threshold_tflite(interpreter, test_ds, thr)
print("\nTest metrics:")
for k, v in test_metrics.items():
    if k not in ["y_true", "y_prob", "cm"]:
        print(f"{k}: {v:.4f}")

# Plot all diagnostic curves for test set
plot_medical_curves(test_metrics["y_true"], test_metrics["y_prob"], threshold=thr)
# Out:
# Best threshold: 0.16904482
#
# Test metrics:
# auc: 0.9766
# precision: 0.9216
# recall: 0.9400
# f1: 0.9307
# specificity: 0.9200
# ROC-AUC: 0.9766
# PR-AUC: 0.9788
